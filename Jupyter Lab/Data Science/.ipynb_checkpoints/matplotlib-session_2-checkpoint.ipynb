# %% [markdown]
# # Matplotlib
# Matplotlib is a desktop plotting package designed for creating (mostly twodimensional) publication-quality plots
# 1. Matplotlib is a Python package for 2D plotting that generates production-quality graphs.
# 2. It supports interactive and non-interactive plotting, and can save images in several output formats (PNG, PS, and others)
# 3. It provides a wide variety of plot types (lines, bars, pie charts, histograms, and many more).
# 4. The dual nature of Matplotlib allows it to be used in both interactive and non-interactive scripts.

# %% [markdown]
# ## Why Matplotlib is so successful
# 1. It uses Python
# 2. It's open source, so no license to pay
# 3. It's a real programming language
# 4. Python has a lot of external modules that will help us perform all the functions we need to. So it's the perfect tool to acquire data, elaborate the data, and then plot the data
# 5. It's very customizable and extensible
# 6. It's integrated with LaTeX markup used for scientific papers
# 7. It's cross-platform and portable

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.arange(3,100,3)
print(data)
plt.plot(data)
# Out:
# [ 3  6  9 12 15 18 21 24 27 30 33 36 39 42 45 48 51 54 57 60 63 66 69 72
#  75 78 81 84 87 90 93 96 99]

# %%
x = np.arange(0.0, 6.0, 0.5)
print(x)
y=[x**2 for x in x]
print(y)
plt.plot(x,y);
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5.  5.5]
# [0.0, 0.25, 1.0, 2.25, 4.0, 6.25, 9.0, 12.25, 16.0, 20.25, 25.0, 30.25]

# %%
t=int(input('enter the number of elements in the list'))
p=[]
l=[]
i=0 
while i<t:
    num=int(input('enter the number ='))
    p.append(num)
    i=i+1
    
print(p)
#for i in p:
 #  l.append(i*i)
l=[i**2 for i in p]
print(l)
# Out:
# enter the number of elements in the list3
# enter the number =1
# enter the number =2
# enter the number =3
# [1, 2, 3]
# [1, 4, 9]

# %% [markdown]
# ### Multiline Plot
# plots are reset after each cell is evaluated, so for more complex plots you must put all of the plotting commands in a single notebook cell<br>

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x])
plt.plot(x, [x**2.25 for x in x])
plt.plot(x, [x**2.5 for x in x]);

# %% [markdown]
# Matplotlib automatically chooses different colors for each line—green for the first line, red for the second line, and blue for the third one (from top to bottom)

# %% [markdown]
# We can plot using single `plot` call

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], x, [x**2.25 for x in x],x, [x**2.5 for x in x]);

# %% [markdown]
# ### Adding a Grid
# We can add a grid to the plot by calling the `grid()` function; it takes one parameter, a Boolean value, to enable (if `True`) or disable (if `False`) the grid

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], x, [x**2.25 for x in x],x, [x**2.5 for x in x])
plt.grid(False)

# %% [markdown]
# ### Handling Axis
# use `plt.axis()`

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], x, [x**2.25 for x in x],x, [x**2.5 for x in x])
plt.axis() # show the value of current axis
# Out:
# (-0.29950000000000004, 6.2895, -4.390733321524976, 92.2053997520245)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], x, [x**2.25 for x in x],x, [x**2.5 for x in x])
plt.grid(True)
plt.axis([0,10,-2,100])  #Specify New Axis
# Out:
# (0.0, 10.0, -2.0, 100.0)

# %% [markdown]
# There are two ways to pass parameters to axis(): by a list of four values or by keyword arguments.
# 1. four values of keyword arguments [xmin, xmax, ymin, ymax]
# 2. specific keyword arguments, for example: plt.axis(xmin=NNN, ymax=NNN)

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], x, [x**2.25 for x in x],x, [x**2.5 for x in x])
plt.grid(True)
plt.axis(xmin=0, ymax=95)
# Out:
# (0.0, 6.2895, -4.390733321524976, 95.0)

# %% [markdown]
# ### Adding Labels
# using `xlabel()` and `ylabel()`

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], x, [x**2.25 for x in x],x, [x**2.5 for x in x])
plt.grid(True)
plt.axis(xmin=-0.5, ymax=95) 
plt.xlabel('This is X Axis')
plt.ylabel('This is Y Axis')
# Out:
# Text(0, 0.5, 'This is Y Axis')

# %% [markdown]
# ### Adding Title
# using `title()` function

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], x,  [x**2.25 for x in x],x, [x**2.5 for x in x])
plt.grid(True)
plt.axis(xmin=-0.5, ymax=95) 
plt.xlabel('This is X Axis')
plt.ylabel('This is Y Axis')
plt.title('Sample Plot')
# Out:
# Text(0.5, 1.0, 'Sample Plot')

# %% [markdown]
# ### Add Legend
# 1. Add extra keyword argument, `label`, to the `plot()` call
# 2. call the `legend()` function with no argument
# <br>**Important** <br>
# Each plot function for each legend should be called seperately
# 1. `plot()` command keeps the track of the line represents, so that information should be there.
# 2. The order of lines plotted is important because the legend() parameters have to be matched with the lines

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], label='Slow')
plt.plot(x, [x**2.25 for x in x], label='Normal')
plt.plot(x, [x**2.5 for x in x], label='Fast')
plt.grid(True)
plt.legend(loc=0)
plt.xlabel('This is X Axis')
plt.ylabel('This is Y Axis')
plt.title('Sample Plot')
# Out:
# Text(0.5, 1.0, 'Sample Plot')

# %% [markdown]
# Options for Legend Position to be used with `plt.legend(loc='XXX')`

# %% [raw]
# best 0
# upper right 1
# upper left 2
# lower left 3
# lower right 4
# right 5
# center left 6
# center right 7
# lower center 8
# upper center 9
# center 10

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], label='Slow')
plt.plot(x, [x**2.25 for x in x], label='Normal')
plt.plot(x, [x**2.5 for x in x], label='Fast')
plt.grid(True)
plt.legend(loc='center left')

# %% [markdown]
# ### Markers and Line Styles
# `plot()` supports an optional third argument for each pair of X, Y arguments:
# `plt.plot(X, Y, '<format>', ...)`

# %% [markdown]
# Three levels of customization:
# 1. Colors
# 2. Line styles
# 3. Marker styles

# %% [markdown]
# ### Color
# List of Color abbrevation and color names<br>
# `b` blue<br>
# `c` cyan<br>
# `g` green<br>
# `k` black<br>
# `m` magenta<br>
# `r` red<br>
# `w` white<br>
# `y` yellow<br>

# %% [markdown]
# Ways to specify color<br>
# 1. The full color name, such as yellow
# 2. Hexadecimal string (the same format as in HTML code) such as #FF00FF
# 3. RGB or RGBA tuples, for example, (1, 0, 1, 1)
# 4. Grayscale intensity, in string format such as '0.7'

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], 'r', label='Slow')
plt.plot(x, [x**2.25 for x in x],'m', label='Normal')
plt.plot(x, [x**2.5 for x in x], 'g', label='Fast')
plt.grid(True)
plt.legend(loc='center left')

# %% [markdown]
# ### Control Line Styles
# List of available styles in Matplotlib<br>
# `-` solid line<br>
# `--` dashed line<br>
# `-.` dash-dot line<br>
# `:` dotted line<br>

# %%
x = np.arange(0.0, 6.0, 0.01)
plt.plot(x, [x**2 for x in x], 'y-', label='Slow')
plt.plot(x, [x**2.25 for x in x],'m-.', label='Normal')
plt.plot(x, [x**2.5 for x in x], 'r:', label='Fast')
plt.grid(True)
plt.legend(loc='center left')

# %% [markdown]
# ### Control Marker Style
# `.` Point marker<br>
# `,` Pixel marker<br>
# `o` Circle marker<br>
# `v` Triangle down marker<br>
# `^` Triangle up marker<br>
# `<` Triangle left marker<br>
# `>` Triangle right marker<br>
# `1` Tripod down marker<br>
# `2` Tripod up marker<br>
# `3` Tripod left marker<br>
# `4` Tripod right marker<br>
# `s` Square marker<br>
# `p` Pentagon marker<br>
# `*` Star marker<br>
# `h` Hexagon marker<br>
# `H` Rotated hexagon marker<br>
# `+` Plus marker<br>
# `x` Cross (x) marker<br>
# `D` Diamond marker<br>
# `d` Thin diamond marker<br>
# `|` Vertical line (vline symbol) marker<br>
# `_` Horizontal line (hline symbol) marker<br>

# %%
x = np.arange(0.0, 6.0, 0.5)
plt.plot(x, [x**2 for x in x], 'ys--', label='Slow')
plt.plot(x, [x**2.25 for x in x],'md-.', label='Normal')
plt.plot(x, [x**2.5 for x in x], 'r+:', label='Fast')
plt.grid(True)
plt.legend(loc='center left')

# %%
x = np.arange(0.0, 6.0, 0.5)
plt.plot(x, [x**2 for x in x], 'ys--', label='Slow')
plt.plot(x, [x**2.25 for x in x],'md-.', label='Normal')
plt.plot(x, [x**2.5 for x in x], 'r+:', label='Fast')
plt.grid(True)
plt.legend(loc='center left')
plt.xticks(range(6),['a','b','c','d','e','f'])
plt.yticks(range(0,90,10),['one','two','three','four','five','six','seven','eight','nine'], rotation=30);

# %% [markdown]
# ## Subplots

# %% [markdown]
# Plots in matplotlib reside within a `Figure` object. You can create a new figure with `plt.figure`

# %% [raw]
# fig = plt.figure()

# %% [markdown]
# `plt.figure` has a number of options<br>
# `figsize` will specify the size and aspect ratio if saved to disk<br>
# You can’t make a plot with a blank figure<br>
# You have to create one or more subplots using `add_subplot`

# %% [raw]
# ax1 = fig.add_subplot(3, 2, 1)

# %% [markdown]
# figure should be 2 × 2 (two rows and two column - total four)<br>
# Third parameter 1 means that we are selecting the first of four subplots<br>

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

ax4.plot(np.random.randn(50).cumsum(), 'k--') #Matplotlib draws on last subplot
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.9)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %% [markdown]
# # Thank You
